# %%
""" 
create a sample text file with some text in it
""";

# %%
# open the file
import os
print(os.listdir(r"C:\Users\Samruddhi Deshmukh\Downloads"))
# Out:
# ['1770474153961-certificate (1).png', '1770474153961-certificate.png', 'Addressing Modes in Microprocessor 8086 Course Content.pdf', 'Anaconda3-2025.12-2-Windows-x86_64 (1).exe', 'Assignment2.ipynb', 'avast_secure_browser_setup.exe', 'b1fc13c5-08c3-4d3a-bd60-764803e1b225 (1).pdf', 'b1fc13c5-08c3-4d3a-bd60-764803e1b225 (2).pdf', 'b1fc13c5-08c3-4d3a-bd60-764803e1b225.pdf', 'desktop.ini', 'eecbbf18.jpg', 'fdc97af2 (1).jpg', 'fdc97af2.jpg', 'jdk-25_windows-x64_bin.msi', 'project_filebrowser.db', 'pycharm-2026.1-aarch64.exe', 'pyhton list que cw (1).pdf', 'python (1).ipynb', 'python.ipynb', 'Python_Coding_Assignment.pdf', 'Python_Weekly_Assignment.pdf', 'Screenshot_8-6-2026_103122_meet.google.com.jpeg', 'SmartConnect', 'string op class.pdf', 'Unconfirmed 314002.crdownload']

# %%
print(file.read())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 print(file.read())
#
# NameError: name 'file' is not defined
