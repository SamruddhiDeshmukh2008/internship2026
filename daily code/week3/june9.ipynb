# %%
"""
create a class called student
create 2-3 objects having attributes name,age

create a methode which will add a skill (eg python, ml,java)to the student
where you can view the info of it later skilles learned by student
""";

# %%
class Student1:

    def __init__ (self, name, age):
        self.name = name
        self.age = age
        self.skills = []

    def add_skill(self, skill):
        return self.skills.append(skill)

# %%
s1 = Student1('samruddhi',18)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s1 = Student1('samruddhi',18)
#
# NameError: name 'Student1' is not defined

# %%
s1.added.skills('java')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s1.added.skills('java')
#
# NameError: name 's1' is not defined

# %% [markdown]
# # inheritance

# %%
class person:
    insti = "mitu"

    def __init__(self,age,ht):
        self.age=age
        self.ht = ht

    def show(self):
        print(f"age {self.age},hight {self.ht}, institute -> {self.insti}")

# %%
class ravi(person):

    def __init__(self,age,ht,sal):
        super().__init__(age,ht)
        self.sal=sal

    def show_sal(salf):
        print(f"salary is {self.sal}")

# %%
a = ravi(18,5.8,90000)

# %%
a.show_sal()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a.show_sal()
#
# Cell In[11], line 8, in ravi.show_sal(salf)
#       7 def show_sal(salf):
# ----> 8     print(f"salary is {self.sal}")
#
# NameError: name 'self' is not defined

# %%
a.show()
# Out:
# age 18,hight 5.8, institute -> mitu

# %% [markdown]
# # polymorphism

# %%
class animal:

    def speak(self):
        return "sound of an animal"

# %%
class dog(animal):
    def speak(self):
        return "woof!!!"
class cat(animal):
    def speak(self):
        return "meow!!!"

# %%
d= dog()
c=cat()

# %%
d.speak()
# Out:
# 'woof!!!'

# %%
c.speak()
# Out:
# 'meow!!!'

# %%
# simple menu driven with oop

# %%
class menuapp:

    def __init__(self):
        self.itemlist =[]
    def show_menu(self):
        print("menu\n 1.add items \n2.view items \n3.exit")

    def add_items(self):
        item = input("enter a the item name:")
        self.itemlist.append(itemlist)
    def view_items(self):
        return self.add_itemlist
    def run(self):

        while True:
            self.show_menu()

            ch=input("enter the  choice")

            if ch ==1:
                self.add_items()
            elif ch == 2:
                self.view_items()
            elif ch == 3:
                break
            else:
                return "inviled choice"

# %%
samruddhi = menuapp()

# %%
samruddhi.run()
# Out:
# menu
#  1.add items
# 2.view items
# 3.exit
# enter the  choice sugar
# 'inviled choice'

# %%
# encapsulation with getter add setter

# %%
class person:
    def __init__(self , age,name):
        self.__age = age
        self.__name = name

    # getter
    def get_name(self):
        return self.name
    def get_age(self,age):
        return self.age
    # setter
    def set_age(self,age):
        self.__age=age

# %%
p= person(34,'sam')

# %%
print(p.get_name())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(p.get_name())
#
# AttributeError: 'person' object has no attribute 'get_name'

# %%
# dunder methodes

# %%
class person:
    def __init__(self , age,name):
        self.__age = age
        self.__name = name

    # getter
    def get_name(self):
        return self.name
    def get_age(self,age):
        return self.age
    # setter
    def set_age(self,age):
        self.__age=age

    def __str__(self):
        return f"age -> {self.__age}, name -> {self.__name}"

# %%
p = person(34,'arun')

# %%
print(p)
# Out:
# age -> 34, name -> arun

# %%
# creat a menu driven app for banking simulation
# check blance ,deposit money, withdraw money (u can add more things as u see fit to make the app better)

# %%
class BankAccount:
    def __init__(self, name, balance=0):
        self.name = name
        self.balance = balance

    def check_balance(self):
        print(f"Balance: ₹{self.balance}")

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited ₹{amount}. New balance: ₹{self.balance}")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew ₹{amount}. New balance: ₹{self.balance}")
        else:
            print("Insufficient balance!")

def banking_app():
    account = BankAccount("Samruddhi", 1000)  # starting balance
    while True:
        print("\n--- Banking Menu ---")
        print("1. Check Balance")
        print("2. Deposit Money")
        print("3. Withdraw Money")
        print("4. Exit")

        ch = input("Enter choice (1-4): ")

        if ch == "1":
            account.check_balance()
        elif ch == "2":
            amt = int(input("Enter deposit amount: "))
            account.deposit(amt)
        elif ch == "3":
            amt = int(input("Enter withdrawal amount: "))
            account.withdraw(amt)
        elif ch == "4":
            print("Exiting... Thank you for banking with us!")
            break
        else:
            print("Invalid choice, try again.")

banking_app()
# Out:
# --- Banking Menu ---
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter choice (1-4):  1
# Balance: ₹1000
#
# --- Banking Menu ---
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter choice (1-4):  2
# Enter deposit amount:  50000000
# Deposited ₹50000000. New balance: ₹50001000
#
# --- Banking Menu ---
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter choice (1-4):  3
# Enter withdrawal amount:  1000
# Withdrew ₹1000. New balance: ₹50000000
#
# --- Banking Menu ---
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter choice (1-4):  4
# Exiting... Thank you for banking with us!
