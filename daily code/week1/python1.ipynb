# %%
Pass = 1

# %%
pass

# %%
Name = "sam"

# %%
Name
# Out:
# 'sam'

# %%
Print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Print(Name)
#
# NameError: name 'Print' is not defined

# %%
print(Name)
# Out:
# sam

# %%
num = 2

num2 = 76.4738

# %%
type(num)
# Out:
# int

# %%
type(num2)
# Out:
# float

# %%
num= 1255427169109 ** 244
num
# Out:
# ...

# %%
# float

# %%
num= 21e3

# %%
type(num)
# Out:
# float

# %%
sent=" i like 'pythone'programing"
print(sent)
# Out:
#  i like 'pythone'programing

# %%
n = 2

# %%
r = 3

# %%
add = n+r

# %%
n=2
num2 =3
add = n+num2
print(sum  )
# Out:
# <built-in function sum>

# %%
a = 2
b = 3
z = a+b
print(z)
# Out:
# 5
