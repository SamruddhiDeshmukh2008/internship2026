# %%
# string

# %%
name = "Sam"

# %%
name.lower()
# Out:
# 'sam'

# %%
name = name.lower()

# %%
name
# Out:
# 'sam'

# %%
name = name.upper()

# %%
name
# Out:
# 'SAM'

# %%
name = "des"

# %%
name.upper()
# Out:
# 'DES'

# %%
name = name.upper()

# %%
name
# Out:
# 'DES'

# %%
name.title()
# Out:
# 'Des'

# %%
name.swapcase()
# Out:
# 'des'

# %%
name
# Out:
# 'DES'

# %%
name.swapcase()
# Out:
# 'des'

# %%
namee = "ssagSdR"

# %%
namee.swapcase()
# Out:
# 'SSAGsDr'

# %%
namee.isupper()
# Out:
# False

# %%
namee.islower()
# Out:
# False

# %%
namee.istitle()
# Out:
# False

# %%
namee.isalpha()
# Out:
# True

# %% [markdown]
# nameee = "ag34"

# %%
nameee = "df45"

# %% [markdown]
# nameee.isalpha()

# %%
nameee.isalpha()
# Out:
# False

# %%
nameee.isalpha()
# Out:
# False

# %%
nameee.isdigit()
# Out:
# True

# %%
namee.isdigit()
# Out:
# False

# %%
nameee.isalnum()
# Out:
# True

# %%
name = " pune "

# %% [markdown]
# name.startswing()

# %%
print(name)
# Out:
#  pune

# %% [raw]
# hh

# %%
name.startswith(" p")
# Out:
# True

# %%
name.endswith(" pune ")
# Out:
# True

# %%
name.endswith("e")
# Out:
# False

# %%
name.startswith(" pune ")
# Out:
# True

# %%
name.lstrip()
# Out:
# 'pune '

# %%
name.rstrip()
# Out:
# ' pune'

# %%
name.strip()
# Out:
# 'pune'

# %%
name = name.strip()

# %%
name
# Out:
# 'pune'

# %%
name.title()
# Out:
# 'Pune'

# %%
len(name)
# Out:
# 4

# %%
name.replace('p', 'oo')
# Out:
# 'ooune'

# %% [markdown]
# # operators

# %%
# arithmatic

# %%
a = 4
b = 12

# %%
a + b
# Out:
# 16

# %%
a - b
# Out:
# -8

# %%
a * b
# Out:
# 48

# %%
a/b
# Out:
# 0.3333333333333333

# %%
a ** b #raste to
# Out:
# 16777216

# %%
b // a # floor div
# Out:
# 3

# %%
a //b # floor div
# Out:
# 0

# %%
b % a
# Out:
# 0

# %%
# assignment operator

# %%
z = 5

# %%
z = z + 3

# %%
z
# Out:
# 8

# %%
z += 3

# %%
z
# Out:
# 11

# %%
z -=3

# %%
z
# Out:
# 8

# %%
z *= 3
z
# Out:
# 157500

# %%
# Out:
# 648

# %%
z /= 6

# %%
z
# Out:
# 26250.0

# %%
# comparison

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
# logical operator

# %%
a = True
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
# identity operator -> is , is not

# %%
a = 5
b = 5

# %%
id(a), id(b)
# Out:
# (140717015737384, 140717015737384)

# %%
a is b
# Out:
# True

# %%
a = [3, 4]
b = [3, 4]

# %%
a is b
# Out:
# False

# %%
id(a), id(b)
# Out:
# (1577475971776, 1577475820928)

# %%
a is not b
# Out:
# True

# %%
z = a

# %%
z
# Out:
# [3, 4]

# %%
z is a
# Out:
# True

# %%
a.append(5)

# %%
a
# Out:
# [3, 4, 5]

# %%
z
# Out:
# [3, 4, 5]

# %%
# membership operator

# %%
l = [2, 3, 4, 5]

# %%
6 in l
# Out:
# False

# %%
4 in l
# Out:
# True

# %%
4 not in l
# Out:
# False

# %%
6 not in l
# Out:
# True

# %% [markdown]
# ## precedent and association

# %%
# bobmas

# %%
5 + 2 - 10
# Out:
# -3

# %%
(4 - 2) ** 2
# Out:
# 4

# %%
2 ** 2 ** 3 # right association
# Out:
# 256

# %%
2 ** 3 // 2
# Out:
# 4

# %%
# print function

# %%
name = "Geet"
marks = 89.57

# %%
# my name is geet and marks are 89.57

# %%
print(name)
# Out:
# Geet

# %%
print(marks)
# Out:
# 89.57

# %%
print(name, marks)
# Out:
# Geet 89.57

# %%
print(marks, name)
# Out:
# 89.57 Geet

# %%
print("my name is", name, "and marks are", marks)
# Out:
# my name is Geet and marks are 89.57

# %%
print("my name is %s and marks are %i" %(name, marks))
# Out:
# my name is Geet and marks are 89

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is Geet and marks are 89.57

# %%
# dir and help

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir(marks)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %%
name.strip()
# Out:
# 'Geet'

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
# ascii values

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(34)
# Out:
# '"'

# %%
chr(35)
# Out:
# '#'

# %%
chr(65)
# Out:
# 'A'

# %%
# type casting

# %%
num1 = 34
num2 = 44.55
num3 = "ok"

# %%
type(num1)
# Out:
# int

# %%
float(num1)
# Out:
# 34.0

# %%
int(num2)
# Out:
# 44

# %%
str(num2)
# Out:
# '44.55'

# %%
str(num1)
# Out:
# '34'

# %%
int(num3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 int(num3)
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %%
# user input

# %%
a = input("enter a first no")
b = input("enter a second no")

z = a + b
print("addition is =>", z)
# Out:
# enter a first no 1
# enter a second no 6
# addition is => 16

# %%
a = int(input("enter a first no"))
b = int(input("enter a second no"))

z = a + b
print("addition is =>", z)
# Out:
# enter a first no 56
# enter a second no 7
# addition is => 63
