# %%
pwd
# Out:
# 'C:\\Users\\Samruddhi Deshmukh'

# %%
num = int(input("enter a number"))

if num > 5:
   print('yes')
# Out:
# enter a number 8
# yes

# %%
num = int(input("enter a number"))

if num > 3:
    print('yes')
else:
    print('no')
# Out:
# enter a number 1
# no

# %%
num = int(input("enter a number"))

if num > 5:
   print('yes')
# Out:
# enter a number 4

# %%
# write a program to check if the number is positive or negative

# %%
num = int(input("enter a number"))
if num > 0:
    print('number is positive')
else:
    print('number is negative')
# Out:
# enter a number -5
# number is negative

# %%
num = int(input("enter a number"))
if num > 0:
    print('number is positive')
else:
    print('number is negative')
# Out:
# enter a number 5
# number is positive

# %%
num = int(input("enter a number"))
if num > 0:
    print('number is positive')
else:
    print('number is negative')
# Out:
# enter a number 0
# number is negative

# %%
num = int(input("enter a number"))
if num > 0:
    print('number is positive')
elif num == 0:
    print('number is zero')
else:
    print('number is negative')
# Out:
# enter a number 0
# number is zero

# %%
# chech the number is even or odd

# %%
num = int(input("enter a number"))

if num % 2 == 0:
    print('even')
else:
    print('odd')
# Out:
# enter a number 4
# even

# %%
num = int(input("enter a number"))

if num % 2 == 0:
    print('even')
else:
    print('odd')
# Out:
# enter a number 3
# odd

# %%
num = int(input("enter a number"))

if num % 2 == 0:
    print('even')
else:
    print('odd')
# Out:
# enter a number 0
# even

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True + True + False
# Out:
# 2

# %%
a = 1

if a:
    print('exists')
# Out:
# exists

# %%
# check the number is in betbeen 50 and 100 or not (use nested if)

# %%
num = int(input("enter a number")) 

if num > 50 and num < 100:
    print('yes')
else:
    print('no')
# Out:
# enter a number 103
# no

# %%
num = int(input("enter a number"))

if num > 50:
    if num < 100:
        print('condition saatisfide')
    else:
        print('greter than 50 but not less than 100')
else:
    print('number is less thane 50')
# Out:
# enter a number 6
# number is less thane 50

# %%
num = int(input("enter a number"))

if num >= 50:
    if num <= 100:
        print('condition saatisfide')
    else:
        print('greter than 50 but not less than 100')
else:
    print('number is less thane 50')
# Out:
# enter a number 50
# condition saatisfide

# %%
# do the same with logical operator

# %%
num = int(input("enter a number"))

if num > 50 and num < 100:
    print('yes')
else:
    print('no')
# Out:
# enter a number 56
# yes

# %%
num = int(input("enter a number"))

if num > 50 and num < 100:
    print('yes')
else:
    print('no')
# Out:
# enter a number 3
# no

# %%
# read purches cost and selling cost frome the user
# state profit or loss and how much

# %%
price1 = int(input("enter a price of purchase"))
price2 = int(input("enter a price of selling"))
 
if price1 < price2:
    print(f"profit of => {price2-price1}")
else:
    print(f"loss of => {price1 - price2}")
# Out:
# enter a price of purchase 45
# enter a price of selling 55
# profit of => 10

# %%
price1 = int(input("enter a price of purchase"))
price2 = int(input("enter a price of selling"))

if price1 < price2:
    print('profit')
else:
    print('loss')
# Out:
# enter a price of purchase 56
# enter a price of selling 43
# loss

# %%
"""
2020->leap 
2017->not leap
2000->leap
1800->not leap
"""
# Out:
# '\n2020->leap \n2017->not leap\n2000->leap\n1800->not leap\n'

# %%
year = int(input("enter a year"))

if year % 4 ==0:
    if year % 100 == 0:
        if year % 400 == 0:
                print('century leap')
        else:
            print('century but not leap')
    else:
        print('leap')
else:
    print('not leap year')
# Out:
# enter a year 2000
# century leap

# %%
"""
take 3 no
find which one is largest (uns nested if only)
"""
# Out:
# '\ntake 3 no\nfind which one is largest (uns nested if only)\n'

# %%
num1 = int(input("enter a first no"))
num2 = int(input("enter a second no"))
num3 = int(input("enter a third no"))

if num1 >= num2:
    if num1 >= num3:       
        print('num1 is large')
    else:
        print('num3 is large')
else:
    if num2>=num3:
        print('num2 is large')
    else:
        print('nu3 is large')
# Out:
# enter a first no 6
# enter a second no 5
# enter a third no 4
# num1 is large

# %%
# menu driven

# %%
print("welcome to the simple calcularor")

num = int(input("enter a number"))

print("menu =>\n1.square\n2.cube\n3.check +ve or -ve")

ch = int(input("select ur choice"))

if ch ==1:
    print(num*num)
    
elif ch ==2:
    print(num ** 3)
    
elif ch == 3:
     if num > 0:
        print('number is positive')
     elif num == 0:
         print('number is zero')
     else:
          print('number is negative')
else:
     print("please enter a 1 to 3 no")
# Out:
# welcome to the simple calcularor
# enter a number 5
# menu =>
# 1.square
# 2.cube
# 3.check +ve or -ve
# select ur choice 2
# 125

# %%
"""
menu driven
take -> 1 upper ,2 loewrcase, 3 replase a particular part of the string
for third option it should which part to replace with what
"""
# Out:
# '\nmenu driven\ntake -> 1 upper ,2 loewrcase, 3 replase a particular part of the string\nfor third option it should which part to replace with what\n'

# %%
print("welcome")

string = input("enter a string")

print("menu =>\n1.upper\n2.lower\n3.replace")

ch = int(input("select ur choice"))

if ch ==1:
    print(f"{text.upper()}")
    
elif ch ==2:
     print(f"{text.lower()}")
    
elif ch == 3:
    string = input("enter a string")
    new = input("Enter the new string: ")
    text = string.replace(string, new)
    print(f"Updated string: {text}")

else:
    print("Invalid choice!")
# Out:
# welcome
# enter a string gs
# menu =>
# 1.upper
# 2.lower
# 3.replace
# select ur choice 3
# enter a string gd
# Enter the new string:  hd
# Updated string: hd
