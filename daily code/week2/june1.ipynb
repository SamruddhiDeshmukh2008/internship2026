# %%
l=[23, 34, 45,56,78]

# %%
print(l)
# Out:
# [23, 34, 45, 56, 78]

# %%
type(l)
# Out:
# list

# %%
# list are hetro and duplicate value are also aloude

# %%
l1 = [12,34,54,46,"python","java",12,34]

# %%
print(l1)
# Out:
# [12, 34, 54, 46, 'python', 'java', 12, 34]

# %%
# list are ordered

# %%
l1
# Out:
# [12, 34, 54, 46, 'python', 'java', 12, 34]

# %%
l1[2]
# Out:
# 54

# %%
l1[-3]
# Out:
# 'java'

# %%
# are mutable

# %%
l1[1]=100

# %%
l1
# Out:
# [12, 100, 54, 46, 'python', 'java', 12, 34]

# %%
l1[-3]=True

# %% [markdown]
# #

# %%
l1
# Out:
# [12, 100, 54, 46, 'python', True, 12, 34]

# %%
# list slicing

# %%
l=[21,34,43,56,65,87]

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
l[1:4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 l[1:4]
#
# NameError: name 'l' is not defined

# %%
l[1:-2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 l[1:-2]
#
# NameError: name 'l' is not defined

# %%
# 21,43,65

# %%
l[0:5:2]
# Out:
# [21, 43, 65]

# %%
l[::2]
# Out:
# [21, 43, 65]

# %%
# reverse the list

# %%
l[::-1]
# Out:
# [87, 65, 56, 43, 34, 21]

# %%
l[1:4]=100,200,300

# %%
l
# Out:
# [21, 100, 200, 300, 65, 87]

# %%
l1=[12,23,34,45]

# %%
l1
# Out:
# [12, 23, 34, 45]

# %%
del l1[-2]

# %%
l1
# Out:
# [12, 23, 45]

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
21 in l
# Out:
# True

# %%
# arathmatic opration on list

# %%
l
# Out:
# [21, 100, 200, 300, 65, 87]

# %%
'ok'*3 # string repeation
# Out:
# 'okokok'

# %%
l * 2  # repeation of list (like string)
# Out:
# [21, 100, 200, 300, 65, 87, 21, 100, 200, 300, 65, 87]

# %%
l*3
# Out:
# [12, 33, 45, 62, 78, 12, 33, 45, 62, 78, 12, 33, 45, 62, 78]

# %%
# take 2 different list and add them

# %%
l = [12,33,45,62,78]
l1= [23,34,56,67,78]

# %%
l
# Out:
# [12, 33, 45, 62, 78]

# %%
l1
# Out:
# [23, 34, 56, 67, 78]

# %%
l+l1
# Out:
# [12, 33, 45, 62, 78, 23, 34, 56, 67, 78]

# %%
# iteration over list

# %%
l
# Out:
# [12, 33, 45, 62, 78]

# %%
# ierate over list and print square of each element

# %%
for i in l:
    print(i**2, end=' ')
# Out:
# 144 1089 2025 3844 6084

# %%
# print odd number in list

# %%
l
# Out:
# [12, 33, 45, 62, 78]

# %%
for i in l:
    if i % 2 != 0:
        print(i , end=' ')
# Out:
# 33 45

# %%
# list comprehension -> syntex -> [expression for_loop if_condition]

# %%
newl= [i**2 for i in l]

# %%
newl
# Out:
# [144, 1089, 2025, 3844, 6084]

# %%
newl1=[i for i in l if i % 2 != 0]

# %%
newl1
# Out:
# [33, 45]

# %%
names=['Aryan', 'atharv', 'samruddhi', 'swaraj', 'Sukanya', 'Shivraj']

# %%
names
# Out:
# ['Aryan', 'atharv', 'samruddhi', 'swaraj', 'Sukanya', 'Shivraj']

# %%
# creat a new list with names which starts with 'S' or 's'

# %%
for i in names:
   if i.lower().startswith('s'):
       print(i)
# Out:
# samruddhi
# swaraj
# Sukanya
# Shivraj

# %%
new3=[i for i in names if i.lower().startswith('s')]

# %%
new3
# Out:
# ['samruddhi', 'swaraj', 'Sukanya', 'Shivraj']

# %%
l
# Out:
# [12, 33, 45, 62, 78]

# %%
len(l)
# Out:
# 5

# %%
max(l)
# Out:
# 78

# %%
min(l)
# Out:
# 12

# %%
sorted(l)
# Out:
# [12, 33, 45, 62, 78]

# %%
sorted(l, reverse = True)
# Out:
# [78, 62, 45, 33, 12]

# %%
# list methodes

# %%
# append

# %%
l
# Out:
# [12, 33, 45, 62, 78]

# %%
l.append(100) # corrent no store the last

# %%
l
# Out:
# [12, 33, 45, 62, 78, 100, 100]

# %%
# extend

# %%
l1 = [1,2,3]
l2 = [1,2,3]

# %%
l1.append([100,200])  
l2.extend([100,200])  # use for store individualy elements

# %%
l1
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
l1
# Out:
# [1, 2, 3, [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
l1[3]
# Out:
# [100, 200]

# %%
l1[3][1]
# Out:
# 200

# %%
l1[3][1]=300

# %%
l1
# Out:
# [1, 2, 3, [100, 300]]

# %%
# insert

# %%
l
# Out:
# [12, 33, 45, 62, 78, 100, 100]

# %%
l.insert(1,100)

# %%
l
# Out:
# [12, 100, 33, 45, 62, 78, 100, 100]

# %%
l.remove(100)

# %%
l
# Out:
# [12, 33, 45, 62, 78, 100, 100]

# %%
# pop

# %%
l.pop()
# Out:
# 100

# %%
l
# Out:
# [12, 33, 45, 62, 78, 100]

# %%
l.pop(3)
# Out:
# 62

# %%
l
# Out:
# [12, 33, 45, 78, 100]

# %%
l.index(45)
# Out:
# 2

# %%
l.sort()

# %%
l
# Out:
# [12, 33, 45, 78, 100]

# %%
l.sort(reverse = True)

# %%
l
# Out:
# [100, 78, 45, 33, 12]

# %%
dir(list)  # methode
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined
