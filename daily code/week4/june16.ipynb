# %%
import numpy as np

# %%
a = np.arange(1000000)
l=list(a)

# %%
import time
time.time()
# Out:
# 1781588164.716335

# %%
# time taken by list

start_time = time.time()
newl = [i*2 for i in l]
time_taken_l = time.time() - start_time

print(f"time taken by list is {time_taken_l}")
# Out:
# time taken by list is 0.20998072624206543

# %%
# time taken by list

start_time = time.time()
newl = a * 2
time_taken_a = time.time() - start_time

print(f"time taken by list is {time_taken_a}")
# Out:
# time taken by list is 0.07936716079711914

# %%
# hoe much faster
time_taken_l / time_taken_a
# Out:
# 2.645687764727087
